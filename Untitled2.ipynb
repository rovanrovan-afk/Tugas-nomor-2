# %% [markdown]
# <a href="https://colab.research.google.com/github/rovanrovan-afk/Tugas-nomor-2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hitung_total_panen(jumlah_kg, harga_per_kg):
    return jumlah_kg * harga_per_kg

def hitung_diskon(total_harga, persentase_diskon):
    return total_harga * (persentase_diskon / 100)

total = hitung_total_panen(100, 15000)
diskon = hitung_diskon(total, 10)
total_akhir = total - diskon

print(f"Total Hasil Panen: Rp{total}")
print(f"Diskon (10%): Rp{diskon}")
print(f"Total Bayar: Rp{total_akhir}")
# Out:
# Total Hasil Panen: Rp1500000
# Diskon (10%): Rp150000.0
# Total Bayar: Rp1350000.0
